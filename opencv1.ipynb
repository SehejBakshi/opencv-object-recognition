# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('computer_mouse.jpg', cv2.IMREAD_GRAYSCALE)
#options available are:
#IMREAD_COLOR = 1
#IMRREAD_UNCHANGED = -1
#IMRAD_GGRAYSCALE = 0
#the nummbers are used sometimes instead of writing the whole thing

# %%
#cv2.imshow('Image', img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
plt.imshow(img, cmap='gray', interpolation='bicubic')
plt.show()
